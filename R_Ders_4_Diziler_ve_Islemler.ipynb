# %% [markdown]
# <a href="https://colab.research.google.com/github/azem46/R_Colab_Notebook/blob/main/R_Ders_4_Diziler_ve_Islemler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DİZİLER**
# Diziler, vektörlerin ve matrislerin genelleştirilmiş halidir. Vektörler tek, matrisler ise iki boyutlu dizilerdir. Diziler, tek tür veri içerebilir. Dizi oluşturmak için array() fonksiyonundan yararlanılır.
#
#
# ---
#
#
#
#
# ### Boş bir dizinin oluşturulması
#
#
#
#
# array(data = NA, dim = length(data), dimnames = NULL)

# %%
array(1:24, dim = c(2, 3, 4))
# Out:
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    3    5
# [2,]    2    4    6
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]    7    9   11
# [2,]    8   10   12
#
# , , 3
#
#      [,1] [,2] [,3]
# [1,]   13   15   17
# [2,]   14   16   18
#
# , , 4
#
#      [,1] [,2] [,3]
# [1,]   19   21   23
# [2,]   20   22   24
